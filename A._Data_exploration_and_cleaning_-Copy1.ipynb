# %% [markdown]
# # A. Data exploration and cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
immo_data = pd.read_csv('Final_dataset_house_apartment.csv', sep=',', na_values='None')

# %%
immo_data
# Out:
#        Unnamed: 0  locality type_of_property   subtype_of_property   price  \
# 0               0      1050            house                 house  340000
# 1               1      1880            house                 villa  525000
# 2               2      4900            house  exceptional property  550000
# 3               3      7912            house                 villa  550000
# 4               4      6032            house                 house  550000
# ...           ...       ...              ...                   ...     ...
# 50837       52072      3120            house                 house  455496
# 50838       52073      1800            house                 house  451650
# 50839       52074      2018            house                 house  488000
# 50840       52075      9140            house                 house  455000
# 50841       52076      9620            house                 house  469000
#
#       type_of_sale  number_of_rooms  house_area  fully_equipped_kitchen  \
# 0         for sale              6.0       203.0                       1
# 1         for sale              6.0       250.0                       1
# 2         for sale             11.0       475.0                       1
# 3         for sale              4.0       325.0                       1
# 4         for sale              5.0       400.0                       1
# ...            ...              ...         ...                     ...
# 50837     for sale              3.0         NaN                       0
# 50838     for sale              3.0         NaN                       0
# 50839     for sale              3.0       145.0                       0
# 50840     for sale              3.0         NaN                       0
# 50841     for sale              3.0         NaN                       0
#
#        furnished  ...  terrace  terrace_area  garden  garden_area  \
# 0            NaN  ...        1           NaN       0          NaN
# 1            NaN  ...        1          40.0       1        430.0
# 2            NaN  ...        1           NaN       1       1400.0
# 3            NaN  ...        1         125.0       1       2333.0
# 4            NaN  ...        1          80.0       1        500.0
# ...          ...  ...      ...           ...     ...          ...
# 50837        NaN  ...        0           NaN       0          NaN
# 50838        NaN  ...        0           NaN       0          NaN
# 50839        NaN  ...        0           NaN       1         48.0
# 50840        NaN  ...        0           NaN       0          NaN
# 50841        NaN  ...        0           NaN       0          NaN
#
#        surface_of_the_land  surface_of_the_plot_of_land  number_of_facades  \
# 0                     95.0                          NaN                2.0
# 1                    826.0                          NaN                4.0
# 2                   1543.0                          NaN                4.0
# 3                   3570.0                          NaN                4.0
# 4                    616.0                          NaN                3.0
# ...                    ...                          ...                ...
# 50837                695.0                          NaN                NaN
# 50838                550.0                          NaN                3.0
# 50839                  0.0                          NaN                3.0
# 50840               1202.0                          NaN                4.0
# 50841               1500.0                          NaN                4.0
#
#        swimming_pool  state_of_the_building construction_year
# 0                  0          to be done up            1901.0
# 1                  0                 as new            1992.0
# 2                  0                   good            1853.0
# 3                  0                   good            1918.0
# 4                  0                 as new            1977.0
# ...              ...                    ...               ...
# 50837              0                    NaN               NaN
# 50838              0                    NaN               NaN
# 50839              0                    NaN               NaN
# 50840              0                    NaN               NaN
# 50841              0                    NaN               NaN
#
# [50842 rows x 21 columns]

# %%
immo_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50842 entries, 0 to 50841
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   50842 non-null  int64
#  1   locality                     50842 non-null  int64
#  2   type_of_property             50842 non-null  object
#  3   subtype_of_property          50842 non-null  object
#  4   price                        50842 non-null  object
#  5   type_of_sale                 50842 non-null  object
#  6   number_of_rooms              50842 non-null  float64
#  7   house_area                   42412 non-null  float64
#  8   fully_equipped_kitchen       50842 non-null  int64
#  9   furnished                    0 non-null      float64
#  10  open_fire                    50842 non-null  int64
#  11  terrace                      50842 non-null  int64
#  12  terrace_area                 17096 non-null  float64
#  13  garden                       50842 non-null  int64
#  14  garden_area                  8350 non-null   float64
#  15  surface_of_the_land          29002 non-null  float64
#  16  surface_of_the_plot_of_land  0 non-null      float64
#  17  number_of_facades            37736 non-null  float64
#  18  swimming_pool                50842 non-null  int64
#  19  state_of_the_building        37670 non-null  object
#  20  construction_year            29883 non-null  float64
# dtypes: float64(9), int64(7), object(5)
# memory usage: 8.1+ MB

# %%
immo_data.describe(include='all')
# Out:
#           Unnamed: 0      locality type_of_property subtype_of_property  \
# count   50842.000000  50842.000000            50842               50842
# unique           NaN           NaN                2                  24
# top              NaN           NaN            house               house
# freq             NaN           NaN            29002               21810
# mean    26154.240903   5388.526081              NaN                 NaN
# std     15053.319249   2958.804834              NaN                 NaN
# min         0.000000   1000.000000              NaN                 NaN
# 25%     13100.250000   2600.000000              NaN                 NaN
# 50%     26332.500000   5030.000000              NaN                 NaN
# 75%     39159.750000   8420.000000              NaN                 NaN
# max     52076.000000   9992.000000              NaN                 NaN
#
#          price type_of_sale  number_of_rooms    house_area  \
# count    50842        50842     50842.000000  42412.000000
# unique    4220            1              NaN           NaN
# top     249000     for sale              NaN           NaN
# freq       674        50842              NaN           NaN
# mean       NaN          NaN         2.828252    154.724158
# std        NaN          NaN         2.221211    185.137627
# min        NaN          NaN         0.000000      1.000000
# 25%        NaN          NaN         2.000000     91.000000
# 50%        NaN          NaN         3.000000    130.000000
# 75%        NaN          NaN         3.000000    186.000000
# max        NaN          NaN       204.000000  31700.000000
#
#         fully_equipped_kitchen  furnished  ...       terrace  terrace_area  \
# count             50842.000000        0.0  ...  50842.000000  17096.000000
# unique                     NaN        NaN  ...           NaN           NaN
# top                        NaN        NaN  ...           NaN           NaN
# freq                       NaN        NaN  ...           NaN           NaN
# mean                  0.654518        NaN  ...      0.562960     23.827737
# std                   0.475530        NaN  ...      0.496025     30.320098
# min                   0.000000        NaN  ...      0.000000      1.000000
# 25%                   0.000000        NaN  ...      0.000000      9.000000
# 50%                   1.000000        NaN  ...      1.000000     16.000000
# 75%                   1.000000        NaN  ...      1.000000     30.000000
# max                   1.000000        NaN  ...      1.000000   1150.000000
#
#               garden    garden_area  surface_of_the_land  \
# count   50842.000000    8350.000000          29002.00000
# unique           NaN            NaN                  NaN
# top              NaN            NaN                  NaN
# freq             NaN            NaN                  NaN
# mean        0.291609     715.837006            999.31484
# std         0.454508    4336.640576           5055.03166
# min         0.000000       1.000000              0.00000
# 25%         0.000000      70.000000            143.00000
# 50%         0.000000     186.000000            351.00000
# 75%         1.000000     540.000000            814.75000
# max         1.000000  312600.000000         400000.00000
#
#         surface_of_the_plot_of_land  number_of_facades  swimming_pool  \
# count                           0.0       37736.000000   50842.000000
# unique                          NaN                NaN            NaN
# top                             NaN                NaN            NaN
# freq                            NaN                NaN            NaN
# mean                            NaN           2.768152       0.015676
# std                             NaN           0.860089       0.124220
# min                             NaN           1.000000       0.000000
# 25%                             NaN           2.000000       0.000000
# 50%                             NaN           3.000000       0.000000
# 75%                             NaN           4.000000       0.000000
# max                             NaN           4.000000       1.000000
#
#         state_of_the_building construction_year
# count                   37670      29883.000000
# unique                      6               NaN
# top                    as new               NaN
# freq                    14358               NaN
# mean                      NaN       1983.587525
# std                       NaN         37.456650
# min                       NaN       1755.000000
# 25%                       NaN       1963.000000
# 50%                       NaN       1992.000000
# 75%                       NaN       2018.000000
# max                       NaN       2048.000000
#
# [11 rows x 21 columns]

# %%
#print(len(df))
#df['price'] = df['price'].replace("no price", np.nan)
#df.dropna(axis=0, inplace=True, subset=['price'])
#print(df[df['price'] == 'no price']['price'])
#print(df[df['price'] == np.nan]['price'])
#print(len(df))
# change la colonne de str -> int
#df['price'] = df['price'].astype('int')
#print(df['price'].dtypes)

# %% [markdown]
# ## Exploratory

# %% [markdown]
# ### missing values

# %%
immo_data.isnull().sum()
# Out:
# Unnamed: 0                         0
# locality                           0
# type_of_property                   0
# subtype_of_property                0
# price                              0
# type_of_sale                       0
# number_of_rooms                    0
# house_area                      8430
# fully_equipped_kitchen             0
# furnished                      50842
# open_fire                          0
# terrace                            0
# terrace_area                   33746
# garden                             0
# garden_area                    42492
# surface_of_the_land            21840
# surface_of_the_plot_of_land    50842
# number_of_facades              13106
# swimming_pool                      0
# state_of_the_building          13172
# construction_year              20959
# dtype: int64

# %% [markdown]
# ### Surface of the land

# %%
immo_data.surface_of_the_land.describe()
# Out:
# count     29002.00000
# mean        999.31484
# std        5055.03166
# min           0.00000
# 25%         143.00000
# 50%         351.00000
# 75%         814.75000
# max      400000.00000
# Name: surface_of_the_land, dtype: float64

# %%
mask_expl_min_surface = immo_data['surface_of_the_land']<10

# %%
immo_data['surface_of_the_land'].loc[mask_expl_min_surface].value_counts()
# Out:
# 0.0    3292
# 1.0      40
# 5.0       5
# 8.0       4
# 7.0       3
# 2.0       2
# 4.0       2
# 6.0       1
# Name: surface_of_the_land, dtype: int64

# %%
immo_data.surface_of_the_land.sort_values(ascending=False)[0:10]
# Out:
# 4718     400000.0
# 49230    358000.0
# 3116     264781.0
# 3925     120775.0
# 50208    120300.0
# 3898     120000.0
# 3092     120000.0
# 77       117800.0
# 46074    100144.0
# 49077     99148.0
# Name: surface_of_the_land, dtype: float64

# %%
mask_limit_max_surface = immo_data['surface_of_the_land']<6000

# %%
plt.hist(immo_data['surface_of_the_land'].loc[mask_limit_max_surface], bins=30)
# Out:
# (array([9476., 6140., 3590., 2315., 1721., 1235.,  810.,  569.,  479.,
#          345.,  279.,  231.,  186.,  153.,  131.,  114.,   92.,   79.,
#           46.,   57.,   69.,   46.,   37.,   42.,   23.,   36.,   34.,
#           25.,   30.,   22.]),
#  array([   0.        ,  199.86666667,  399.73333333,  599.6       ,
#          799.46666667,  999.33333333, 1199.2       , 1399.06666667,
#         1598.93333333, 1798.8       , 1998.66666667, 2198.53333333,
#         2398.4       , 2598.26666667, 2798.13333333, 2998.        ,
#         3197.86666667, 3397.73333333, 3597.6       , 3797.46666667,
#         3997.33333333, 4197.2       , 4397.06666667, 4596.93333333,
#         4796.8       , 4996.66666667, 5196.53333333, 5396.4       ,
#         5596.26666667, 5796.13333333, 5996.        ]),
#  <a list of 30 Patch objects>)

# %% [markdown]
# suggestion cleaning :
# - max : ok, pas anormal d'avoir terrain de plusieurs hectares
# - min : 3332 valeurs < 5 m² --> as Nan ?

# %% [markdown]
# ### number of façades

# %%
immo_data.number_of_facades.value_counts()
# Out:
# 2.0    17834
# 4.0    10093
# 3.0     9305
# 1.0      504
# Name: number_of_facades, dtype: int64

# %%
immo_data.number_of_facades.isnull().sum()
# Out:
# 13106

# %%
plt.hist(immo_data.number_of_facades)
# Out:
# (array([  504.,     0.,     0., 17834.,     0.,     0.,  9305.,     0.,
#             0., 10093.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# suggestion cleaning :
# - ok

# %% [markdown]
# ### swimming pool

# %%
immo_data.swimming_pool.value_counts()
# Out:
# 0    50045
# 1      797
# Name: swimming_pool, dtype: int64

# %% [markdown]
# suggestion cleaning :
# - ok

# %% [markdown]
# ### Etat du building

# %%
immo_data.state_of_the_building.value_counts()
# Out:
# as new            14358
# good              13457
# to be done up      3670
# to renovate        3392
# just renovated     2577
# to restore          216
# Name: state_of_the_building, dtype: int64

# %%
immo_data.state_of_the_building.isnull().sum()
# Out:
# 13172

# %% [markdown]
# suggestion cleaning :
# - ok

# %% [markdown]
# ### Année de construction

# %%
immo_data.construction_year.value_counts()
# Out:
# 2020.0    3766
# 2019.0    2211
# 2018.0    1021
# 1930.0     636
# 1970.0     601
#           ...
# 1822.0       1
# 1801.0       1
# 1809.0       1
# 1781.0       1
# 1791.0       1
# Name: construction_year, Length: 219, dtype: int64

# %%
immo_data.construction_year.isnull().sum()
# Out:
# 20959

# %% [markdown]
# suggestion cleaning :
# - ok

# %% [markdown]
# ### House area

# %%
immo_data[immo_data['house_area']<=5]
# Out:
#        Unnamed: 0  locality type_of_property subtype_of_property   price  \
# 5807         5920      8840        apartment           apartment  135000
# 7283         7457      8870        apartment           apartment  125000
# 19968       20734      3290        apartment           apartment  265000
# 24040       24912      8400        apartment           apartment  425000
# 38260       39290      8954            house               house  265500
# 43951       45094      4845            house               villa  323000
# 44188       45335      4845            house               villa  307000
# 44576       45726      8791            house               house  335000
#
#       type_of_sale  number_of_rooms  house_area  fully_equipped_kitchen  \
# 5807      for sale              0.0         5.0                       0
# 7283      for sale              4.0         5.0                       0
# 19968     for sale              2.0         1.0                       0
# 24040     for sale              2.0         1.0                       0
# 38260     for sale              3.0         5.0                       1
# 43951     for sale              4.0         1.0                       0
# 44188     for sale              3.0         1.0                       0
# 44576     for sale              4.0         5.0                       1
#
#        furnished  ...  terrace_area  garden  garden_area  surface_of_the_land  \
# 5807         NaN  ...           NaN       0          NaN                  NaN
# 7283         NaN  ...           NaN       0          NaN                  NaN
# 19968        NaN  ...           NaN       1          NaN                  NaN
# 24040        NaN  ...           NaN       0          NaN                  NaN
# 38260        NaN  ...           NaN       0          NaN                373.0
# 43951        NaN  ...           NaN       0          NaN                913.0
# 44188        NaN  ...           NaN       1        500.0                  0.0
# 44576        NaN  ...           NaN       0          NaN                484.0
#
#        surface_of_the_plot_of_land  number_of_facades  swimming_pool  \
# 5807                           NaN                NaN              0
# 7283                           NaN                NaN              0
# 19968                          NaN                NaN              0
# 24040                          NaN                2.0              0
# 38260                          NaN                NaN              0
# 43951                          NaN                NaN              0
# 44188                          NaN                4.0              0
# 44576                          NaN                NaN              0
#
#        state_of_the_building  construction_year house_area_cat
# 5807                    good                NaN      [0-60 m²]
# 7283                  as new                NaN      [0-60 m²]
# 19968                    NaN                NaN      [0-60 m²]
# 24040                   good             1961.0      [0-60 m²]
# 38260                 as new             2019.0      [0-60 m²]
# 43951                 as new             2013.0      [0-60 m²]
# 44188                 as new             2019.0      [0-60 m²]
# 44576                   good             1956.0      [0-60 m²]
#
# [8 rows x 22 columns]

# %%
immo_data[immo_data['house_area']>=1500]
# Out:
#        Unnamed: 0  locality type_of_property subtype_of_property   price  \
# 1793         1801      4470            house               house  585000
# 1795         1803      4470            house     apartment block  585000
# 2481         2497      9600            house               house  650000
# 3536         3563      2880            house         manor house  750000
# 15435       15938      3000        apartment                 kot  250000
# 33122       34082      7050            house  mixed use building  175000
# 34666       35652      8400            house               house  219000
# 35298       36287      4800            house     apartment block  250000
# 38503       39538      5670            house     apartment block  300000
# 45853       47024      6560            house  mixed use building  395000
# 46074       47249      6698            house     country cottage  399000
# 47698       48899      7140            house  mixed use building  360000
# 47699       48900      7140            house     apartment block  360000
# 47768       48969      6200            house  mixed use building  399000
#
#       type_of_sale  number_of_rooms  house_area  fully_equipped_kitchen  \
# 1793      for sale             18.0      1500.0                       1
# 1795      for sale             18.0      1500.0                       1
# 2481      for sale              1.0      1640.0                       0
# 3536      for sale              3.0      3560.0                       1
# 15435     for sale              1.0     31700.0                       1
# 33122     for sale              2.0      1700.0                       0
# 34666     for sale              4.0      2019.0                       0
# 35298     for sale             20.0      2400.0                       0
# 38503     for sale              0.0      2500.0                       0
# 45853     for sale              6.0      1500.0                       0
# 46074     for sale              0.0      2562.0                       0
# 47698     for sale              0.0      1900.0                       0
# 47699     for sale              0.0      1900.0                       0
# 47768     for sale              0.0      1525.0                       0
#
#        furnished  ...  terrace_area  garden  garden_area  surface_of_the_land  \
# 1793         NaN  ...           NaN       0          NaN               2500.0
# 1795         NaN  ...           NaN       0          NaN               2500.0
# 2481         NaN  ...           NaN       0          NaN               1640.0
# 3536         NaN  ...          24.0       1       3560.0               3560.0
# 15435        NaN  ...           NaN       0          NaN                  NaN
# 33122        NaN  ...           NaN       0          NaN               1700.0
# 34666        NaN  ...           NaN       0          NaN                165.0
# 35298        NaN  ...           NaN       0          NaN               1667.0
# 38503        NaN  ...           NaN       1      20000.0              22072.0
# 45853        NaN  ...           NaN       0          NaN                  0.0
# 46074        NaN  ...           NaN       0          NaN             100144.0
# 47698        NaN  ...           NaN       0          NaN                  0.0
# 47699        NaN  ...           NaN       0          NaN                  0.0
# 47768        NaN  ...           NaN       0          NaN                790.0
#
#        surface_of_the_plot_of_land  number_of_facades  swimming_pool  \
# 1793                           NaN                NaN              0
# 1795                           NaN                NaN              0
# 2481                           NaN                3.0              0
# 3536                           NaN                4.0              0
# 15435                          NaN                NaN              0
# 33122                          NaN                4.0              0
# 34666                          NaN                2.0              0
# 35298                          NaN                2.0              0
# 38503                          NaN                4.0              0
# 45853                          NaN                3.0              0
# 46074                          NaN                4.0              0
# 47698                          NaN                3.0              0
# 47699                          NaN                3.0              0
# 47768                          NaN                2.0              0
#
#        state_of_the_building  construction_year house_area_cat
# 1793              to restore                NaN        ]240- ]
# 1795              to restore                NaN        ]240- ]
# 2481                    good             1991.0        ]240- ]
# 3536                    good             1979.0        ]240- ]
# 15435                 as new                NaN        ]240- ]
# 33122            to renovate                NaN        ]240- ]
# 34666                    NaN                NaN        ]240- ]
# 35298                   good                NaN        ]240- ]
# 38503                    NaN                NaN        ]240- ]
# 45853                   good                NaN        ]240- ]
# 46074                    NaN                NaN        ]240- ]
# 47698                    NaN                NaN        ]240- ]
# 47699                    NaN                NaN        ]240- ]
# 47768                   good                NaN        ]240- ]
#
# [14 rows x 22 columns]

# %% [markdown]
# suggestion cleaning :
# - 8 valeurs <= 5 m² --> as NaN ?
# - 15 valeurs >= 1500 m² --> as Nan ?

# %% [markdown]
# ## Suppression de variables inutiles

# %%
#df = df.drop(labels='type_of_sale', axis=1)
#df = df.drop(labels='furnished', axis=1)
#df = df.drop(labels='surface_of_the_plot_of_land', axis=1)
